# %% [markdown]
# <a href="https://colab.research.google.com/github/HarisMalisevic/dsai-idav-2025-26/blob/main/Lab01_ExploratoryDataAnalysis_SurnameName.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 01 – Exploratory Data Analysis
# ### Course: Introduction to Data Analysis and Visualisation
# **Objective:** Understand data types, data cleaning, and visualization design principles using Python (pandas, matplotlib, seaborn).
# **File name convention:** `Lab01_ExploratoryDataAnalysis_SurnameName.ipynb`

# %% [markdown]
# ## Environment Setup

# %%
# --- Setup ---
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: prettier display
sns.set_theme(style="whitegrid")

# Check versions
print("pandas:", pd.__version__)
print("seaborn:", sns.__version__)
# Out:
# pandas: 2.2.2
# seaborn: 0.13.2

# %% [markdown]
# ## Loading Data

# %%
# --- Load Dataset ---

# Example 1: Load from seaborn’s sample datasets (1)
df = sns.load_dataset("penguins")

# Example 2 (commented out): Load a CSV file
# from google.colab import files
# uploaded = files.upload()
# df = pd.read_csv("your_dataset.csv")

# Preview
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# (1) The Seaborn library provides predefined sample datasets, more at: https://github.com/mwaskom/seaborn-data
#
# ---

# %% [markdown]
# ## Data Overview

# %%
# --- Data Overview ---
print("Shape:", df.shape)
print("\nData types:\n", df.dtypes)
print("\nMissing values:\n", df.isna().sum())

# Numeric summary
print("\nNumeric summary:\n", df.describe())

# Categorical summary (safe version)
categorical_cols = df.select_dtypes(include=['object', 'category']).columns

if len(categorical_cols) > 0:
    print("\nCategorical summary:\n", df[categorical_cols].describe())
else:
    print("\nNo categorical columns found.")


# Show first and last rows
display(df.head(), df.tail())
# Out:
# Shape: (344, 7)
#
# Data types:
#  species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object
#
# Missing values:
#  species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64
#
# Numeric summary:
#         bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# ...

# %% [markdown]
# ### Describe DataFrame

# %%
# --- TASK: Define a function that prints DataFrame properties ---

def describe_dataframe(df):
    """
    Display DataFrame properties:
    - Shape
    - Column data types
    - Missing values
    - Numeric statistics
    - Categorical statistics
    - Sample rows
    """
    # TODO: Implement here
    pass

# Example call:
# describe_dataframe(df)

# %% [markdown]
# ## Basic Visualisation

# %%
# --- Basic Visualizations ---

# Bar plot example
sns.barplot(x='species', y='bill_length_mm', data=df)
plt.title("Average Bill by Day")
plt.show()

# Scatter example
sns.scatterplot(x='flipper_length_mm', y='body_mass_g', hue='sex', data=df)
plt.title("Flipper Length vs Body Mass by Sex")
plt.show()

# %% [markdown]
# # Tasks

# %% [markdown]
# 1. Create a copy of the starting Notebook. Follow the given naming convention. ```Lab01_DataFoundations_SurnameName.ipynb```
#
# 2. Run the code. Verify that the data loads and that the charts appear on screen. Identify and fix potential errors.
#
#
#
# 3. Write a Python function ```named describe_dataframe(df)``` that displays key properties of a Pandas DataFrame in a clear and structured way.
#
#     **Requirements:**
#
#     Function definition
#     * The function must have exactly one argument: a Pandas DataFrame (df).
#     * Enforce that the argument is a DataFrame.
#
#     Structure and readability
#     * The main function should be clean and easy to read.
#     * Each logical part of the analysis (e.g., shape, missing values, etc.) should be implemented as a separate helper function.
#     * Use clear print formatting and section headers to make the output easy to interpret.
#
#     Your function must display the following DataFrame properties:
#     * Shape: number of rows and columns.
#     * Column data types for all columns.
#     * Missing values analysis: count and percentage of missing values per column.
#     * Numeric column statistics: summary statistics (mean, median, min, max, std, etc.).
#     * Categorical column analysis: count of unique values, most frequent value, and its frequency.
#     * Sample rows: first five and last five rows of the DataFrame.
#
#     **Ensure that the output is well-formatted and human-readable.**
#
#
#
#
# 4. Write a Python function named `save_csv_to_google_drive(df)` that exports a Pandas DataFrame to a CSV file and saves it to your Google Drive using your ETF email account. The CSV file name should include a timestamp to avoid overwriting previous exports (e.g., `data_export_2025-10-20_12-30.csv`)
#
#
#
# 5. Graph the relationship between penguin body mass and flipper length. Is body mass normally distributed?
#
#
#
# 6. Pick one species of penguin.
# Extract data for that species to a new DataFrame named species_df.
# Calculate the correlation coefficient between numerical variables in the new DataFrame.
# Export the DataFrame to your Google Drive using ```save_csv_to_google_drive(df)```.
